# %%
cd ../
# Out:
# /home/anna/PycharmProjects/DataJournalismApp

# %%
import pandas as pd
import util.stats_util as su

# %%
path = "data/processed/news33_processed"
data = pd.read_parquet(path)
data.head()
# Out:
#         _time        date                                               tags  \
# 0  1564617600  01.08.2019      праздники во Владимирской области август 2019
# 1  1559174400  30.05.2019  плохая погода град гроза ветер, погода во Влад...
# 2  1548892800  31.01.2019  Женская колония Головино Владимирская область ...
# 3  1548720000  29.01.2019                  Собинский район проишествия кража
# 4  1548028800  21.01.2019            адвоката судят за мошенничество Владмир
#
#                                                title         topic  \
# 0  Где владимирцам отдохнуть и повеселиться в пер...      Общество
# 1          Владимирцев в выходные ждет плохая погода      Общество
# 2  В женской колонии обучают нянь по уходу за детьми      Общество
# 3  Житель Собинки украл свиное копыто и получил у...  Происшествия
# 4      Владимирский адвокат сел на скамью подсудимых  Происшествия
#
#                                             keywords      source  \
# ...

# %%
su.collect_stat(data, "topic", "Рубрика", group_name='Количество статей')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-d290932538f0> in <module>
# ----> 1 su.collect_stat(data, "topic", "Рубрика", group_name='Количество статей')
#
# TypeError: collect_stat() missing 1 required positional argument: 'name_csv'
